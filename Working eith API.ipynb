# %%
import numpy as np
import pandas as pd

import matplotlib as plt
import seaborn as sns
# %matplotlib inline

import requests as rq
import json

# %%
r = rq.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers')
res = r.json()

# %%
sunflower_ids = res['objectIDs']
len(sunflower_ids)
# Out:
# 87

# %%
r_test = rq.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/437980')
obj_test = r_test.json()
print(obj_test['GalleryNumber'])
print(obj_test['culture'])
print(obj_test['title'])
print(obj_test['objectName'])
print(obj_test['objectID'])
print(obj_test['department'])
print(obj_test['artistDisplayName'])
obj_test
# Out:
# 825
#
# Cypresses
# Painting
# 437980
# European Paintings
# Vincent van Gogh
# {'objectID': 437980,
#  'isHighlight': False,
#  'accessionNumber': '49.30',
#  'accessionYear': '1949',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ep/original/DP130999.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ep/web-large/DP130999.jpg',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 161947,
#    'role': 'Artist',
#    'name': 'Vincent van Gogh',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#    'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#    'gender': ''}],
#  'department': 'European Paintings',
#  'objectName': 'Painting',
#  'title': 'Cypresses',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Artist',
#  'artistPrefix': '',
#  'artistDisplayName': 'Vincent van Gogh',
# ...

# %%
r_test = rq.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/704667')
obj_test = r_test.json()
obj_test
# pd.DataFrame({'objectID': obj_test['objectID'], 'title': obj_test['title'], 'artistDisplayName': obj_test['artistDisplayName'],
#  'department': obj_test['department'], 'objectBeginDate': obj_test['objectBeginDate'], 'objectEndDate': obj_test['objectEndDate'],
#  'period': obj_test['period'], 'objectName': obj_test['objectName'], 'culture': obj_test['culture']}, index=[0])
# Out:
# {'message': 'Not a valid object'}

# %%
df = pd.DataFrame()
for id in sunflower_ids:
    r_test = rq.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/' + str(id))
    obj_test = r_test.json()
    try:
        df = pd.concat([df, pd.DataFrame({'objectID': obj_test['objectID'], 'title': obj_test['title'], 'artistDisplayName': obj_test['artistDisplayName'],
 'department': obj_test['department'], 'objectBeginDate': obj_test['objectBeginDate'], 'objectEndDate': obj_test['objectEndDate'],
 'period': obj_test['period'], 'objectName': obj_test['objectName'], 'culture': obj_test['culture']}, index=[0])], ignore_index=True)
    
    except:
        continue
df
# Out:
#     objectID                                              title  \
# 0     436524                                         Sunflowers
# 1     484935                                         Sunflowers
# 2     437112                              Bouquet of Sunflowers
# 3     210191                               Vase with sunflowers
# 4     431264                                         Sunflowers
# ..       ...                                                ...
# 79    436144            James-Jacques-Joseph Tissot (1836–1902)
# 80    437980                                          Cypresses
# 81    834585  A Life in a Year–The Garden–Noon, from "Pictur...
# 82    834580  A Life in a Year–The Garden–Noon, from "Pictur...
# 83    834765           A Child's Garden, from "Picture Poesies"
#
#            artistDisplayName                              department  \
# 0           Vincent van Gogh                      European Paintings
# ...

# %%
r = rq.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
cat_ids = r.json()
cat_ids = cat_ids['objectIDs']
r_test = rq.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/' + str(id))
obj_test = r_test.json()
obj_test
# Out:
# {'objectID': 75747,
#  'isHighlight': False,
#  'accessionNumber': '2015.300.104.1, .2',
#  'accessionYear': '2015',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/as/original/DP362563.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/as/web-large/DP362563.jpg',
#  'additionalImages': ['https://images.metmuseum.org/CRDImages/as/original/DP362569.jpg',
#   'https://images.metmuseum.org/CRDImages/as/original/DP362566.jpg',
#   'https://images.metmuseum.org/CRDImages/as/original/DP362567.jpg',
#   'https://images.metmuseum.org/CRDImages/as/original/DP362568.jpg',
#   'https://images.metmuseum.org/CRDImages/as/original/DP362570.jpg',
#   'https://images.metmuseum.org/CRDImages/as/original/DP362571.jpg',
#   'https://images.metmuseum.org/CRDImages/as/original/DP362572.jpg'],
#  'constituents': None,
#  'department': 'Asian Art',
#  'objectName': 'Screens',
# ...

# %%
df_cats = pd.DataFrame()

for id in cat_ids[:1000]:
    r_test = rq.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/' + str(id))
    obj_test = r_test.json()
    try:
        df_cats = pd.concat([df, pd.DataFrame({'objectID': obj_test['objectID'], 'title': obj_test['title'], 'artistDisplayName': obj_test['artistDisplayName'],
 'department': obj_test['department'], 'objectBeginDate': obj_test['objectBeginDate'], 'objectEndDate': obj_test['objectEndDate'],
 'period': obj_test['period'], 'objectName': obj_test['objectName'], 'culture': obj_test['culture']}, index=[0])], ignore_index=True)
    
    except:
        continue
df_cats
# Out:
#      objectID                                              title  \
# 0      436524                                         Sunflowers
# 1      484935                                         Sunflowers
# 2      437112                              Bouquet of Sunflowers
# 3      210191                               Vase with sunflowers
# 4      431264                                         Sunflowers
# ..        ...                                                ...
# 230     58779  Case (Inrō) with Design of Flowering Peonies (...
# 231     73046                              Forest Scene with Cat
# 232    671015  The Third Princess with her Cat, from the "New...
# 233     45065              Onna San no Miya (the Third Princess)
# 234     46968                                       Square Flask
#
#             artistDisplayName                              department  \
# 0            Vincent van Gogh                      European Paintings
# ...

# %%
df_cats.value_counts('period')
# Out:
# period
#                                                111
# Edo period (1615–1868)                          43
# Qing dynasty (1644–1911)                        23
# Edo (1615–1868) or Meiji period (1868–1912)     13
# Meiji period (1868–1912)                        13
# pre-Angkor period                               10
# Han dynasty (206 B.C.–A.D. 220)                  4
# Muromachi period (1392–1573)                     2
# Mon-Dvaravati period                             2
# Khmer Empire (802–1431)                          2
# Song dynasty (960–1279) or later                 2
# Central Javanese period                          2
# Momoyama period (1573–1615)                      1
# Ming dynasty (?) (1368–1644)                     1
# Ming dynasty (1368–1644)                         1
# Western Han dynasty (206 B.C.–A.D. 9)            1
# Kushan period                                    1
# Heian period (794–1185)                          1
# ...
